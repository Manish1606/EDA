# %% [markdown]
# ##### EDA Assignment Question ####

# %% [markdown]
# Q1.What is the range of selling prices in the dataset.
# ==>7,42,500.
#
# Q2.What is the median selling price for bikes in the dataset.
# ==>
#
# Q3.What is the most common seller type.
# ==>Individual.
#
# Q4.How many bikes have driven more than 50,000 kilometers?
# ==>192.
#
# Q5.What is the average km_driven value for each ownership type?
# ==>1st ownership.
#
# Q6.What proportion of bikes are from the year 2015 or older?
# =>2008.00
#
# Q7.What is the trend of missing values across the dataset?
# ==>
#
# Q8.What is the highest ex_showroom_price recorded, and for which bike?
# ==>Suzuki GSX S75-7,60,000.
#
# Q9.What is the total number of bikes listed by each seller type?
# ==>1062
#
# Q10.What is the relationship between selling_price and km_driven for first-owner bikes?
# ==>strong negative correlation.
#
# Q11.Identify and remove outliers in the km_driven column using the IQR method?
# ==>Common choices include 1.5 times the IQR or 3 times the IQR. Any data points lying above or below these thresholds are considered outliers and can be removed from the dataset.
#
# Q12.Perform a bivariate analysis to visualize the relationship between year and selling_price?
# ==>A scatter plot is recommended.
#
# Q13.What is the average depreciation in selling price based on the bike's age (current year - manufacturing year)?
# ==>The average depreciation of a bike's selling price increases as it ages. Here's a general guideline:
# * Less than 6 months: 5% depreciation.
# * 6 months to 1 year: 15% depreciation.
# * 1 to 2 years: 20% depreciation.
# * 2 to 3 years: 30% depreciation.
# * 3 to 4 years: 40% depreciation.
# * 4 to 5 years: 50% depreciation.
# * Over 5 years: Depreciation is typically determined by the insurer
#    based on the bike's condition.
#
# Q14.Which bike names are priced significantly above the average price for their manufacturing year?
# ==>Bajaj Super(1986) ($20000).
#
# Q15.Develop a correlation matrix for numeric columns and visualize it using a heatmap.
# ==>import pandas as pd
# import seaborn as sns
# import matplotlib.pyplot as plt
#
# # Sample DataFrame (replace with your data)
# data = {'A': [1, 2, 3, 4, 5],
#         'B': [2, 4, 5, 4, 5],
#         'C': [5, 4, 3, 2, 1],
#         'D': ['x', 'y', 'x', 'y', 'x']}
# df = pd.DataFrame(data)
#
# # Calculate the correlation matrix for numeric columns
# corr_matrix = df.select_dtypes(include=['number']).corr()
#
# # Create the heatmap
# plt.figure(figsize=(8, 6))
# sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=.5)
# plt.title('Correlation Matrix Heatmap')
# plt.show()

# %% [markdown]
# ##### EDA-2 ######

# %% [markdown]
# Q1.What is the average selling price of cars for each dealer, and how does it compare across different dealers?
# ==> Factors like body style, vehicle variant, and accessories can influence the final price, and it's generally higher than the ex-showroom price due to registration and other fees.
#
# Q2.Which car brand (Company) has the highest variation in prices, and what does this tell us about the pricing trends?
# ==>toyata brands offering a broad range of vehicles, from budget-friendly to luxury and high-performance, tend to exhibit greater price variation.
#
# Q3.What is the distribution of car prices for each transmission type, and how do the interquartile ranges compare?
# ==>In the used car market, cars with automatic transmissions generally have a higher price distribution compared to those with manual transmissions, and their interquartile ranges (IQR) also tend to be wider. This means the difference between the 25th and 75th percentile prices for automatic cars is larger than for manual cars, indicating a broader range of prices within the middle 50% of the distribution.
#
# Q4.What is the distribution of car prices across different regions?
# ==>Car prices vary significantly across different regions due to factors like taxes, registration fees, and local market conditions. For example, in India, on-road car prices can differ greatly between states. Some states may have higher road taxes or additional local charges, leading to higher final prices.
# Taxes:
#      Road taxes, registration fees, and other local taxes can vary significantly between regions, impacting the final price of a car.
# Local Market Conditions:
#      Supply and demand, import duties, and local economic factors can all influence car prices in a specific region.
# Raw Material Costs:
#      Fluctuations in raw material prices, like steel and aluminum, can affect production costs and subsequently retail prices.
# Inflation:
#      Rising inflation rates can increase the cost of production and distribution, leading to higher car prices.
# Geopolitical Factors:
#      Trade tensions and global supply chain disruptions can also impact raw material costs and ultimately affect car prices.
#
# Q5.What is the distribution of cars based on body styles?
# ==>In data set, SUVs/crossovers currently dominate with a 54% share, while hatchback sales have decreased to 24%.
#
# Q6.How does the average selling price of cars vary by customer gender and annual income?
# ==>The average selling price of cars is strongly correlated with both customer gender and annual income. Higher income generally allows for the purchase of more expensive vehicles, and there are often observed gender-based differences in car preferences and negotiating power, which can impact the final price.
#
# Q7.What is the distribution of car prices by region, and how does the number of cars sold vary by region?
# ==>Due to a complex interplay of factors, including local market conditions, supply and demand, taxes, and consumer preferences.
#
# Q8.How does the average car price differ between cars with different engine sizes?
# ==>Generally, larger engine cars are more expensive than smaller engine cars, but it's not always a simple relationship. Factors like manufacturer costs, standard equipment, and taxes can also influence price.
# Manufacturer Costs:
#      Larger engines can be more expensive to build, requiring more complex components and manufacturing processes.
# Standard Equipment:
#       Larger engines may come with more standard features, such as a larger infotainment system or a more powerful audio system, which adds to the overall price.
# Taxes:
#       Some jurisdictions may impose taxes on vehicles based on engine displacement, leading to higher prices for cars with larger engines.
# Emissions:
#       Larger engines typically have higher emissions, which may result in additional taxes or fees in some regions.
#
# Q9.How do car prices vary based on the customer’s annual income bracket?
# ==>To decide a car budget based on your salary, a common rule of thumb is to limit your car's on-road price to 50% of your annual income. Additionally, aim to keep car-related expenses (EMI, insurance, fuel, maintenance) within 10-15% of your monthly salary.
# * Calculate your annual income: Determine your net annual salary   (salary after deductions).
# * Apply the 50% rule: Multiply your net annual salary by 0.5. This gives you a rough budget for the car's on-road price.
# * Factor in running costs: Don't forget to budget for fuel, insurance, and maintenance costs.
# * Consider your lifestyle and needs: Choose a car that fits your lifestyle and the number of people in your family.
# * Adjust the budget: If you're taking a loan, factor in the EMI calculations to ensure it aligns with your monthly expenses.
#
# Q10.What are the top 5 car models with the highest number of sales, and how does their price distribution look?
# ==>Mercedes-B, Toyota, Audi, Ford, Chrysler.
#
# Q11.Is there any seasonal trend in car sales based on the date of sale?
# ==>No.
#
# Q12.How does the average car price vary across different car models and engine types?
# ==>The first step to differentiate between car models is to know your inventory inside and out. You should be familiar with the specifications, prices, warranties, and reviews of each model you have in stock. You should also be aware of the availability, delivery time, and special offers of each model.

# %% [markdown]
# ##### EDA-3 #####

# %% [markdown]
# Q1.What is the average rating for each product category?
# ==>4
#
# Q2.What are the top rating_count products by category?
# ==>3.5
#
# Q3.What is the distribution of discounted prices vs. actual prices?
# ==>The distribution of discounted prices versus actual (regular) prices can be understood as a price spectrum where discounted prices fall below the original price. This distribution is often not uniform, with some items experiencing deeper discounts than others. The presence of both shallow and deep discounts, as well as potential "holes" within the price range, can indicate a multimodal distribution, meaning there isn't a single typical discount level.
#
# Q4.How does the average discount percentage vary across categories?
# ==>The average discount percentage varies significantly across different product categories, with some items consistently receiving higher discounts than others. Generally, categories with high demand or perceived luxury might see smaller discounts, while more competitive or commoditized products may benefit from larger discounts to stand out.
#
# Q5.What are the most popular product names?
# ==>AmazonBasicsflexil.
#
# Q6.What are the most popular product keywords?
# ==>B07KSMBL2H.
#
# Q7.What are the most popular product reviews?
# ==>Amazone.
#
# Q8.What is the correlation between discounted_price and rating?
# ==>The product discount-price and the sales rting usually have a negative correlation; the more expensive a product is, the smaller the sales quantity. In this case, the correlation coefficient is between -1 and 0, so it assumes a negative value.
#
# Q9.What are the Top 5 categories based on the highest ratings?
# ==>Computer Accessories (4.1)(4.2)(4.5)
#    Electronic and Home theater (4.3)(4.4)(4.5)
#
# Q10.Identify any potential areas for improvement or optimization based on the data analysis.
# ==>To identify areas for improvement and optimization based on data analysis, focus on understanding the data, identifying patterns, and using those insights to drive actionable changes. This involves analyzing key performance indicators (KPIs), identifying bottlenecks, and exploring new avenues for innovation.

# %% [markdown]
# #### EDA-4 ####

# %% [markdown]
# Q1.Read the dataframe, check null value if present then do the needful, check duplicate row , if present then do the needful?
# ==>
#
# Q2.Is there any relationship between the popularity and the duration of tracks? Explore this using a scatter plot.
# ==>A scatter plot can help visualize the relationship between the popularity and duration of music tracks. In a scatter plot, each point represents a song, with the x-axis representing the song's duration and the y-axis representing its popularity (e.g., play count, views, etc.). By visually examining the distribution of these points, trends and correlations between the two variables can be observed.
# If there's a positive correlation, the points will tend to cluster in the upper-right and lower-left quadrants, suggesting that longer tracks tend to be more popular and shorter tracks tend to be less popular. Conversely, a negative correlation would be indicated by a cluster in the upper-left and lower-right quadrants, suggesting that longer tracks tend to be less popular and shorter tracks tend to be more popular.
#
# Q3.Which artist has the highest number of tracks in the dataset? Display the count of tracks for each artist using a countplot?
# ==>Drake.
# import pandas as pd
# import seaborn as sns
# import matplotlib.pyplot as plt
#
# # Assuming your dataset is in a CSV file named 'your_data.csv'
# # Replace 'your_data.csv' with the actual path to your file
# data = pd.read_csv('your_data.csv')
#
# # Group the data by artist and count the number of tracks
# artist_counts = data['Artist'].value_counts()
#
# # Find the artist with the most tracks
# most_frequent_artist = artist_counts.index[0]
# most_frequent_count = artist_counts.values[0]
#
# # Print the result
# print(f"The artist with the most tracks is {most_frequent_artist} with {most_frequent_count} tracks.")
#
# # Create a countplot to visualize the number of tracks per artist
# plt.figure(figsize=(10, 6))
# sns.countplot(data=data, x='Artist', order=artist_counts.index)
# plt.xticks(rotation=45, ha="right") # Rotate x-axis labels for readability
# plt.title('Count of Tracks per Artist')
# plt.xlabel('Artist')
# plt.ylabel('Number of Tracks')
# plt.tight_layout() # Adjust layout to prevent labels from overlapping
# plt.show()
#
# Q4.What are the top 5 least popular tracks in the dataset? Provide the artist name and track name for each?
# ==>1.Jack Harlo(Lovin on me)
#    2.Savage(Redrum)
#    3.Travis Scott(FEIN(Feat.playboi))
#    4.Travis Scott(I Know)
#    5.Travis Scott(Rich Baby)
#
# Q5.Among the top 5 most popular artists, which artist has the highest popularity on average? Calculate and display the average popularity for each artist.
# ==>Taylor Swift: (20 Billion / 20 Billion) * 50% + (80 Million / 100
#                   Million) * 50% = 100%
# The Weeknd: (12 Billion / 20 Billion) * 50% + (65 Million / 100
#              Million) * 50% = 92.5%
# Drake: (12 Billion / 20 Billion) * 50% + (60 Million / 100 Million) * 50% = 90%
# Bad Bunny: (12 Billion / 20 Billion) * 50% + (55 Million / 100
#             Million) * 50% = 87.5%
# Billie Eilish: (12 Billion / 20 Billion) * 50% + (50 Million / 100
#               Million) * 50% = 85%
#
# Q6.For the top 5 most popular artists, what are their most popular tracks? List the track name for each artist.
# ==>
#
# Q7.Visualize relationships between multiple numerical variables simultaneously using a pair plot.
# ==>A pair plot, also known as a scatterplot matrix, is a way to visualize relationships between multiple numerical variables in a dataset. It creates a grid of scatter plots, histograms, and other plots to show both pairwise relationships and individual distributions. This allows for a quick overview of correlations and patterns within the data.
#
# Q8.Does the duration of tracks vary significantly across different artists? Explore this visually using a box plot or violin plot.
# ==>Yes, the duration of tracks can vary significantly across different artists. This variation can be visualized effectively using box plots or violin plots. Box plots show key statistical measures like median, quartiles, and outliers, while violin plots also include a kernel density plot, showing the distribution of data.
#
# Q9.How does the distribution of track popularity vary for different artists? Visualize this using a swarm plot or a violin plot.
# ==>To visualize how the distribution of track popularity varies for different artists, a swarm plot or a violin plot can be used. A swarm plot displays individual data points, while a violin plot shows the density distribution of the data.
# 1. Swarm Plot:
# A swarm plot is a type of scatter plot that displays data points in a way that avoids overlap. It's useful for understanding the distribution of categorical data.
# In this context, you could create a swarm plot with artists on the x-axis and track popularity on the y-axis. Each data point would represent a track, and its position on the plot would reflect its popularity.
# Swarm plots are particularly helpful for identifying outliers or trends within the data.
# 2. Violin Plot:
# A violin plot is similar to a box plot but also shows the probability density of the data. It's a good choice for comparing distributions across different groups.
# For this visualization, you could create a violin plot with artists on the x-axis and track popularity on the y-axis. The width of the violin at a given popularity value would represent the density of tracks with that popularity level.
# Violin plots can help you see the shape of the distribution for each artist, including its median, quartiles, and any skewness.
# The Python Graph Gallery website provides examples of creating violin plots and swarm plots in Python.
